# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report,roc_auc_score,accuracy_score
from tqdm import tqdm

# %% [markdown]
# ##  Abstract:
# ### Predict whether income exceeds 50K/yr  based on census data. Also known as "Census Income" dataset.

# %%
columns = ['age','workclass','fnlwgt','education','education-num',
          'marital-status','occupation','relationship','race','sex',
          'capital-gain','capital-loss','hours-per-week','native-country','income']

# %%
# # names = pd.read_csv('data/adult.names', error_bad_lines=False)
df = pd.read_csv('data/adult.data', names=columns)
# test = pd.read_csv('data/adult.test')
# index = pd.read_csv("data/index")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### Verificando a quantidade de valores nulos e Nan:

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# ### Por questões de padronização da informação, substitui os valores categóricos de "income" para:
# ### <= 50k/yr  =  0
# ### > 50k/yr  =  1

# %%
df.income.value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
df["income"]= df["income"].replace(' <=50K', 0) 
df["income"]= df["income"].replace(' >50K', 1)

# %%
df.income.value_counts()
# Out:
# 0    24720
# 1     7841
# Name: income, dtype: int64

# %% [markdown]
# ## Estatisticas Descritivas
#
# #### 1.1 - Escolher dois atributos quaisquer e calcular suas estatísticas descritivas (global e por classe), organizando-as conforme tabela abaixo.

# %% [markdown]
# ### Globais

# %%
df['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df['hours-per-week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %% [markdown]
# ### Por classes, classe 0:

# %%
dfClass1 = df[df['income']==0]

# %%
dfClass1.shape
# Out:
# (24720, 15)

# %%
dfClass1['age'].describe()
# Out:
# count    24720.000000
# mean        36.783738
# std         14.020088
# min         17.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max         90.000000
# Name: age, dtype: float64

# %%
dfClass1['hours-per-week'].describe()
# Out:
# count    24720.000000
# mean        38.840210
# std         12.318995
# min          1.000000
# 25%         35.000000
# 50%         40.000000
# 75%         40.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %% [markdown]
# ### Por classes, classe 1:

# %%
dfClass2 = df[df['income']==1]

# %%
dfClass2.shape
# Out:
# (7841, 15)

# %%
dfClass2['age'].describe()
# Out:
# count    7841.000000
# mean       44.249841
# std        10.519028
# min        19.000000
# 25%        36.000000
# 50%        44.000000
# 75%        51.000000
# max        90.000000
# Name: age, dtype: float64

# %%
dfClass2['hours-per-week'].describe()
# Out:
# count    7841.000000
# mean       45.473026
# std        11.012971
# min         1.000000
# 25%        40.000000
# 50%        40.000000
# 75%        50.000000
# max        99.000000
# Name: hours-per-week, dtype: float64

# %% [markdown]
# ### 1.2 – Escolha uma das classes (de preferência a que possuir mais dados) e estime o (i) seu centróide e (ii) sua matriz de covariância. Mostrar como foi realizado/feito/implementado este subitem.

# %%
dfClass1
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
print(dfClass1['age'].sum())
print(len(dfClass1['age']))
print(dfClass1['age'].mean())
# Out:
# 909294
# 24720
# 36.78373786407767

# %%
dfClass1.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.078905      -0.051501      0.053572      0.029794
# fnlwgt         -0.078905  1.000000      -0.054418     -0.000130     -0.012997
# education-num  -0.051501 -0.054418       1.000000      0.011695      0.016375
# capital-gain    0.053572 -0.000130       0.011695      1.000000     -0.026413
# capital-loss    0.029794 -0.012997       0.016375     -0.026413      1.000000
# hours-per-week  0.046286 -0.021430       0.082319      0.017938      0.018695
# income               NaN       NaN            NaN           NaN           NaN
#
#                 hours-per-week  income
# age                   0.046286     NaN
# fnlwgt               -0.021430     NaN
# education-num         0.082319     NaN
# capital-gain          0.017938     NaN
# capital-loss          0.018695     NaN
# hours-per-week        1.000000     NaN
# income                     NaN     NaN

# %% [markdown]
# ###  1.3 – Para a classe do Subitem 1.2, fazer o gráfico de dispersão dos atributos escolhidos para resolução do Subitem 1.1. Colocar nomes dos atributos nos eixos dos gráficos.

# %%
plt.figure(figsize=(10,10))
plt.title('Scatter plot')
plt.xlabel('Age')
plt.ylabel('Hours-per-week')
plt.scatter(x=dfClass1['age'],y=dfClass1['hours-per-week'])
plt.show()

# %% [markdown]
# ### 1.4 – O diagrama de dispersão do Subitem 1.3 indica a existência de algum tipo de correlação entre os dois atributos escolhidos? Detalhe sua resposta.

# %% [markdown]
# Acredito que não exista correlação grande entre age e hours-per-week

# %% [markdown]
# ### 1.5 - Estimar o coeficiente de correlação entre os dois atributos escolhidos para resolução do Subitem 1.3 para a classe escolhida. Mostrar os cálculos e qual método/procedimento foi utilizado para realizá-los.

# %%
dfClass1[['age','hours-per-week']].corr()
# Out:
#                      age  hours-per-week
# age             1.000000        0.046286
# hours-per-week  0.046286        1.000000

# %% [markdown]
# ### 1.6 – Determinar os parâmetros a (inclinação) e b (intercepto) da reta de tendência para os gráfico de dispersão mostrado no Subitem 1.3. Mostrar os cálculos e qual método/procedimento foi utilizado

# %% [markdown]
# Como não há relação de reta (no caso, uma reta de tendência) entre essas duas variáveis, não tem como calcular valores de inclinação e nem de intercepto.

# %% [markdown]
# ### 1.7 - Escolha um dos atributos usados na resolução do Subitem 1.1 e gere o histograma correspondente para uma classe de sua escolha. A distribuição do atributo escolhido assemelha-se a uma gaussiana? Há suspeita de presença de outliers nos dados? Detalhe sua resposta.

# %%
dfClass1['hours-per-week'].plot(kind='hist')

# %% [markdown]
# Como mostrado no gráfico, há uma certa "tendência" para um gráfico gaussiano.
# Sobre a presença de outlier, não há consideravelmente a presença de outliers, talvez alguns entre 80 - 100, onde, pelo gráfico, encontra-se valores mais distantes da normal que possuem uma certa frequencia de dados.

# %%
med = dfClass1['hours-per-week'].mean()
std = dfClass1['hours-per-week'].std()
a = (med-std)
b = (med+std)
c = (med-2*std)
d = (med+2*std)
e = (med-3*std)
f = (med+3*std)

# %%
df[df['hours-per-week'].between(a, b)]
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       39      State-gov   77516      Bachelors             13
# 2       38        Private  215646        HS-grad              9
# 3       53        Private  234721           11th              7
# 4       28        Private  338409      Bachelors             13
# 5       37        Private  284582        Masters             14
# ...    ...            ...     ...            ...            ...
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
### Outra maneira de fazer a mesma análise

# %%
df[(df['hours-per-week'] >= a) & (df['hours-per-week'] <= b)]
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       39      State-gov   77516      Bachelors             13
# 2       38        Private  215646        HS-grad              9
# 3       53        Private  234721           11th              7
# 4       28        Private  338409      Bachelors             13
# 5       37        Private  284582        Masters             14
# ...    ...            ...     ...            ...            ...
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df[df['hours-per-week'].between(a, b)]
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       39      State-gov   77516      Bachelors             13
# 2       38        Private  215646        HS-grad              9
# 3       53        Private  234721           11th              7
# 4       28        Private  338409      Bachelors             13
# 5       37        Private  284582        Masters             14
# ...    ...            ...     ...            ...            ...
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### media - sigma / media + sigma

# %%
len(dfClass1[dfClass1['hours-per-week'].between(a, b)])/len(dfClass1)
# Out:
# 0.7637944983818771

# %% [markdown]
# ### media - 2 * sigma / media + 2 * sigma

# %%
len(dfClass1[dfClass1['hours-per-week'].between(c, d)])/len(dfClass1)
# Out:
# 0.9360436893203884

# %% [markdown]
# ### media - 3 * sigma / media + 3 * sigma

# %%
len(dfClass1[dfClass1['hours-per-week'].between(e, f)])/len(dfClass1)
# Out:
# 0.9898058252427184

# %%
dfClass1['hours-per-week']
# Out:
# 0        40
# 1        13
# 2        40
# 3        40
# 4        40
#          ..
# 32553    11
# 32555    40
# 32556    38
# 32558    40
# 32559    20
# Name: hours-per-week, Length: 24720, dtype: int64

# %% [markdown]
# ### 1.8 – Aplique o método de Box-Cox aos dados do Subitem 1.7 e, em seguida, aplique a transformação z-score (normalização para média zero e variância unitária). Forneça o histograma para o novo conjunto de medidas. A distribuição dos novos dados ficou mais próxima de uma gaussiana? Detalhe sua resposta.

# %%
# import modules 
import numpy as np 
from scipy import stats 
  
# plotting modules 
import seaborn as sns 
import matplotlib.pyplot as plt 
  
# generate non-normal data (exponential) 
original_data = np.asarray(dfClass1['hours-per-week'].values)



# transform training data & save lambda value 
fitted_data, fitted_lambda = stats.boxcox(original_data)
  
# creating axes to draw plots 
fig, ax = plt.subplots(1, 2) 
  
# plotting the original data(non-normal) and  
# fitted data (normal) 
sns.distplot(original_data, hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "Non-Normal", color ="green", ax = ax[0]) 
  
sns.distplot(fitted_data, hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "Normal", color ="green", ax = ax[1]) 
  
# adding legends to the subplots 
plt.legend(loc = "upper right") 
  
# rescaling the subplots 
fig.set_figheight(5) 
fig.set_figwidth(10)

# %%
print(f"Lambda value: {fitted_lambda}")
# Out:
# Lambda value: 1.003149546943228

# %%
from scipy import stats
zFittedData = stats.zscore(fitted_data)

# %%
fitted_data.mean()
# Out:
# 38.177008538338455

# %%
medZero = zFittedData.mean()
varUnitaria = zFittedData.var()

# %%
print("nova média : ",medZero)
print("nova variancia : ", varUnitaria)
# Out:
# nova média :  1.996245671461932e-16
# nova variancia :  0.9999999999999999

# %%
med = zFittedData.mean()
std = zFittedData.std()
a = (med-std)
b = (med+std)
c = (med-2*std)
d = (med+2*std)
e = (med-3*std)
f = (med+3*std)

# %%
fittedNormal = pd.DataFrame(zFittedData,columns=['Values'])

# %%
len(fittedNormal[fittedNormal['Values'].between(a, b)])/len(fittedNormal)
# Out:
# 0.7637944983818771

# %%
len(fittedNormal[fittedNormal['Values'].between(c, d)])/len(fittedNormal)
# Out:
# 0.9360436893203884

# %%
len(fittedNormal[fittedNormal['Values'].between(e, f)])/len(fittedNormal)
# Out:
# 0.9898058252427184

# %%
plt.hist(original_data)
# Out:
# (array([  671.,  2062.,  2159., 14103.,  2043.,  2149.,  1020.,   292.,
#           123.,    98.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(zFittedData)
# Out:
# (array([  671.,  2062.,  2159., 14103.,  3586.,   606.,  1020.,   292.,
#           123.,    98.]),
#  array([-3.06426278, -2.26859179, -1.47292081, -0.67724982,  0.11842116,
#          0.91409215,  1.70976313,  2.50543412,  3.3011051 ,  4.09677609,
#          4.89244707]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(zFittedData)

# %% [markdown]
# Apesar das transformações feitas, podemos ver que os dados ainda comportam-se da maneira análoga a análisada anteriormente, graficamente possui uma certa "tendência" a gaussiana, porém ao levantar as métricas estatísticas, vemos que não está tão próximo aos valores de "limite" de uma distribuição normal.

# %% [markdown]
# ## Item 2 (Classificação de Padrões):

# %% [markdown]
# ## Pré-Processamento

# %% [markdown]
# ### Verificando cardinalidade

# %%
df['native-country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [markdown]
# ### Coletando a quantidade de colunas que passam de 10 valores diferentes dentro dela (cardinalidade), julgo cardinalidade '10' como um valor limite para utilizar One-Hot encoder, mas é algo a ser discutido e estudado.

# %%
object_cols = [col for col in df.columns if df[col].dtype == "object"]
count=0
for col in object_cols:
    if df[col].nunique() > 10:
        count+=1
count
# Out:
# 3

# %%
## Coletando para as colunas object, o numero de diferentes valores para a coluna.
object_nunique = list(map(lambda col: df[col].nunique(), object_cols))
d = dict(zip(object_cols, object_nunique))

## Ordenando as informações em um dicionário, onde o primeiro valor é a coluna e o segundo a quantidade de valores diferentes
## dessa coluna
sorted(d.items(), key=lambda x: x[1])
# Out:
# [('sex', 2),
#  ('race', 5),
#  ('relationship', 6),
#  ('marital-status', 7),
#  ('workclass', 9),
#  ('occupation', 15),
#  ('education', 16),
#  ('native-country', 42)]

# %% [markdown]
# ### Adicionando a uma lista de colunas apenas as colunas que possuem cardinalidade <= 10

# %%
colToEncode = []
for col in object_cols:
    if df[col].nunique() <= 10:
        colToEncode.append(col)

# %%
colToEncode
# Out:
# ['workclass', 'marital-status', 'relationship', 'race', 'sex']

# %%
testDummies = pd.get_dummies(df[colToEncode], prefix=colToEncode)

# %%
testDummies
# Out:
#        workclass_ ?  workclass_ Federal-gov  workclass_ Local-gov  \
# 0                 0                       0                     0
# 1                 0                       0                     0
# 2                 0                       0                     0
# 3                 0                       0                     0
# 4                 0                       0                     0
# ...             ...                     ...                   ...
# 32556             0                       0                     0
# 32557             0                       0                     0
# 32558             0                       0                     0
# 32559             0                       0                     0
# 32560             0                       0                     0
#
#        workclass_ Never-worked  workclass_ Private  workclass_ Self-emp-inc  \
# 0                            0                   0                        0
# ...

# %%
object_cols
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country']

# %%
# Remove categorical columns (will replace with one-hot encoding)
df = df.drop(object_cols, axis=1)

# %%
# Add one-hot encoded columns to numerical features
dfFinal = pd.concat([df, testDummies], axis=1)

# %% [markdown]
# ### Algumas colunas em específico, depois de realizar one-hot-encoder, me chamaram atenção:

# %%
dfFinal['workclass_ Never-worked'].value_counts()
# Out:
# 0    32554
# 1        7
# Name: workclass_ Never-worked, dtype: int64

# %%
dfFinal['workclass_ Never-worked'].mean()
# Out:
# 0.00021498111237369858

# %%
dfFinal['workclass_ Without-pay'].value_counts()
# Out:
# 0    32547
# 1       14
# Name: workclass_ Without-pay, dtype: int64

# %%
dfFinal['workclass_ Without-pay'].mean()
# Out:
# 0.00042996222474739717

# %%
dfFinal.describe().T
# Out:
#                                          count           mean            std  \
# age                                    32561.0      38.581647      13.640433
# fnlwgt                                 32561.0  189778.366512  105549.977697
# education-num                          32561.0      10.080679       2.572720
# capital-gain                           32561.0    1077.648844    7385.292085
# capital-loss                           32561.0      87.303830     402.960219
# hours-per-week                         32561.0      40.437456      12.347429
# income                                 32561.0       0.240810       0.427581
# workclass_ ?                           32561.0       0.056386       0.230670
# workclass_ Federal-gov                 32561.0       0.029483       0.169159
# workclass_ Local-gov                   32561.0       0.064279       0.245254
# workclass_ Never-worked                32561.0       0.000215       0.014661
# ...

# %% [markdown]
# ### Train-test split

# %%
X = dfFinal.drop(['income'],axis=1)
y = dfFinal['income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train.value_counts()

# %%
y_test.value_counts()

# %%
dfFinal['income']

# %%
# dfFinal.to_csv("adult.csv",index=None)

# %% [markdown]
# ### Classic KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
neigh = KNeighborsClassifier(n_jobs=1)
neigh.fit(X_train, y_train)

y_pred= neigh.predict(X_test)

confusion_matrix(y_test,y_pred)

# %%
print(classification_report(y_test,y_pred))

# %%
accuracy_score(y_test,y_pred)

# %%
pd.Series(y_pred).value_counts()

# %% [markdown]
# ###  Metodologia: Separar aleatoriamente 80% do conjunto de vetores para treinar o classificador linear dos mínimos quadrados e os 20% restantes serão usados para testar.  Repetir 100 vezes o procedimento de treino-teste e determinar as estatísticas da tabela após as 100 rodadas.

# %%
accArrays=[]
class1Count=[]
class0Count=[]
dictResults = {}

for i in tqdm(range(100)):
    X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    neigh = KNeighborsClassifier(n_jobs=-1)
    neigh.fit(X_train, y_train)
    y_pred= neigh.predict(X_test)
    
    accArrays = (accuracy_score(y_test,y_pred))
    class1Count = (pd.Series(y_pred).value_counts()[1])
    class0Count = (pd.Series(y_pred).value_counts()[0])
    dictResults[i] = [accArrays,class0Count,class1Count]

# %%
accArrays

# %%
print(np.mean(accArrays))
print(np.std(accArrays))
print(np.median(accArrays))
print(np.min(accArrays))
print(np.max(accArrays))

# %%
print(np.mean(class1Count))
print(np.std(class1Count))
print(np.median(class1Count))
print(np.min(class1Count))
print(np.max(class1Count))

# %%
print(np.mean(class0Count))
print(np.std(class0Count))
print(np.median(class0Count))
print(np.min(class0Count))
print(np.max(class0Count))

# %%
confusion_matrix(y_test,y_pred)

# %%
print(classification_report(y_test,y_pred))

# %%
roc_auc_score(y_test,y_pred)

# %% [markdown]
# ### Classificador Linear de Mínimos Quadrados

# %%
from sklearn.linear_model import RidgeClassifier
clf = RidgeClassifier().fit(X_train, y_train)
clf.score(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred

# %%
print(classification_report(y_test,y_pred))

# %%
accArrays_LS=[]
class1Count_LS=[]
class0Count_LS=[]
dictResults_LS = {}

for i in tqdm(range(100)):
    X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    clf = RidgeClassifier().fit(X_train, y_train)
    y_pred= clf.predict(X_test)
    
    accArrays_LS= (accuracy_score(y_test,y_pred))
    class1Count_LS = (pd.Series(y_pred).value_counts()[1])
    class0Count_LS = (pd.Series(y_pred).value_counts()[0])
    dictResults_LS[i] = [accArrays_LS,class0Count_LS,class1Count_LS]

# %%
dictResults_LS

# %%
LS_results = pd.DataFrame.from_records(dictResults_LS).T

# %%
LS_results.rename({0:'Accuracy',1:'Class0_values',2:'Class1_values'},axis=1,inplace=True)

# %%
print('Media_:',np.mean(LS_results['Accuracy']))
print('Desvio Padrão_:',np.std(LS_results['Accuracy']))
print('Mediana_:',np.median(LS_results['Accuracy']))
print('Mínimo_:',np.min(LS_results['Accuracy']))
print('Máximo_:',np.max(LS_results['Accuracy']))

# %%
print('Media_:',np.mean(LS_results['Class0_values']))
print('Desvio Padrão_:',np.std(LS_results['Class0_values']))
print('Mediana_:',np.median(LS_results['Class0_values']))
print('Mínimo_:',np.min(LS_results['Class0_values']))
print('Máximo_:',np.max(LS_results['Class0_values']))

# %%
print('Media_:',np.mean(LS_results['Class1_values']))
print('Desvio Padrão_:',np.std(LS_results['Class1_values']))
print('Mediana_:',np.median(LS_results['Class1_values']))
print('Mínimo_:',np.min(LS_results['Class1_values']))
print('Máximo_:',np.max(LS_results['Class1_values']))

# %% [markdown]
# ### Classificador Quadratico

# %%
  % Partition of training data into K subsets
  for k=1:K,
    I=find(Dtrn(:,end)==k);  % Find rows with samples from k-th class
    X{k}=Dtrn(I,1:end-1); % Data samples from k-th class
    m{k}=mean(X{k})';   % Centroid of the k-th class
    S{k}=cov(X{k});     % Covariance matrix of the k-th class
    posto{k}=rank(S{k}); % Check invertibility of covariance matrix by its rank
    iS{k}=pinv(S{k});    % Inverse covariance matrix of the k-th class
    disp(iS{k});
    # %iS{k}=inv(S{k});    % Inverse covariance matrix of the k-th class
  end

  
  % Testing phase
  correct=0;  % number correct classifications
  for i=1:Ntst,
    Xtst=Dtst(i,1:end-1)';   % test sample to be classified
    Label_Xtst=Dtst(i,end);   % Actual label of the test sample
    for k=1:K,
      v=(Xtst-m{k});
      dist(k)=v'*iS{k}*v;  % Mahalanobis distance to k-th class
    end
    [dummy Pred_class]=min(dist);  % index of the minimum distance class
    
    if Pred_class == Label_Xtst,
        correct=correct+1;
    end
  end

# %%
X.describe().T
# Out:
#                                          count           mean            std  \
# age                                    32561.0      38.581647      13.640433
# fnlwgt                                 32561.0  189778.366512  105549.977697
# education-num                          32561.0      10.080679       2.572720
# capital-gain                           32561.0    1077.648844    7385.292085
# capital-loss                           32561.0      87.303830     402.960219
# hours-per-week                         32561.0      40.437456      12.347429
# workclass_ ?                           32561.0       0.056386       0.230670
# workclass_ Federal-gov                 32561.0       0.029483       0.169159
# workclass_ Local-gov                   32561.0       0.064279       0.245254
# workclass_ Never-worked                32561.0       0.000215       0.014661
# workclass_ Private                     32561.0       0.697030       0.459549
# ...

# %%
X_0.describe().T
# Out:
#                                         count           mean            std  \
# age                                    6290.0      44.231479      10.533827
# fnlwgt                                 6290.0  187372.894754  102503.147208
# education-num                          6290.0      11.615580       2.391499
# capital-gain                           6290.0    3903.295707   14285.432844
# capital-loss                           6290.0     192.051033     591.109966
# hours-per-week                         6290.0      45.493800      10.908911
# workclass_ ?                           6290.0       0.023847       0.152586
# workclass_ Federal-gov                 6290.0       0.049285       0.216479
# workclass_ Local-gov                   6290.0       0.078537       0.269037
# workclass_ Never-worked                6290.0       0.000000       0.000000
# workclass_ Private                     6290.0       0.631002       0.482572
# ...

# %%
X_1 = X.loc[y_train[y_train==1].index]
X_0 = X.loc[y_train[y_train==0].index]

# %%
centroid1 = pd.DataFrame(X_1,columns=X_1.columns).mean()
centroid0 = pd.DataFrame(X_1,columns=X_0.columns).mean()
dict_centroids = {0: centroid0,
                  1: centroid1}

# %%
ainv[0][0]

# %%
ainv =

# %%
CONV1 = X_1.cov().to_numpy()
CONV0 = X_0.cov().to_numpy()

# %%
len(CONV1)

# %%
np.matrix(CONV1)

# %%
# %%time
# invCONV1 = np.linalg.inv(CONV1)
invCONV0 = np.linalg.inv(CONV0)

# %%
del CONV1
del CONV0

# %%
dict_invCONV = {0: invCONV0,
                  1: invCONV1}

# %%
dict_invCONV[0].shape

# %%
invCONV1

# %%
# %%time
autovalores_1, autovetores_1 = np.linalg.eig(CONV1)
autovalores_0, autovetores_0 = np.linalg.eig(CONV0)

# %%
k=2 ##Numero de classes
dist={}

for test_values in tqdm(X_test):
    for i in range(k):
        print(i)
        v = (test_values - dict_centroids[i].values)
        convMult = np.dot(dict_invCONV[i],v)
        dist[i] = np.dot(v.T,convMult)

# %%
np.dot(dict_invCONV[0],v)

# %%
v = (test_values - dict_centroids[i].values)

# %%
X_test - centroid1

# %%
v=(Xtst-m{k});
dist(k)=v'*iS{k}*v;

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test,y_pred))

# %%
len(clf.decision_function(X_train))

# %%
clf.get_params()

# %%
accArrays_QD=[]
class1Count_QD=[]
class0Count_QD=[]
dictResults_QD = {}

for i in tqdm(range(100)):
    X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    clf = QuadraticDiscriminantAnalysis().fit(X_train, y_train)
    y_pred= clf.predict(X_test)
    
    accArrays_QD= (accuracy_score(y_test,y_pred))
    class1Count_QD = (pd.Series(y_pred).value_counts()[1])
    class0Count_QD = (pd.Series(y_pred).value_counts()[0])
    dictResults_QD[i] = [accArrays_QD,class0Count_QD,class1Count_QD]

# %%
QD_results = pd.DataFrame.from_records(dictResults_QD).T

# %%
QD_results.rename({0:'Accuracy',1:'Class0_values',2:'Class1_values'},axis=1,inplace=True)

# %%
QD_results.describe()

# %%
print('Mediana_:',np.median(QD_results['Accuracy']))

# %%
print('Media_:',np.mean(LS_results['Accuracy']))
print('Desvio Padrão_:',np.std(LS_results['Accuracy']))
print('Mediana_:',np.median(LS_results['Accuracy']))
print('Mínimo_:',np.min(LS_results['Accuracy']))
print('Máximo_:',np.max(LS_results['Accuracy']))
